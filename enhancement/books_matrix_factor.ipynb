# %%
"""
Uses cosine similarity.
Filters only books where at least 500 reviews are present.
"""


import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
books_df = pd.read_csv("../data/Books.csv")
users_df = pd.read_csv("../data/Users.csv")
ratings_df = pd.read_csv("../data/ratings.csv")
# Out:
# C:\Users\NelsonWang\AppData\Local\Temp\ipykernel_23224\3971019450.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv("../data/Books.csv")

# %%
ratings_df.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
# Clean up
# 1. Find the user ID of those who have rater either too few books (<5) and too many books (>200)
# 2. Remove those users from the ratings_df

valid_transaction_df = ratings_df.groupby('User-ID').filter(lambda x: len(x) > 5 and len(x) < 200)
valid_transaction_df.groupby('User-ID').size().sort_values(ascending=False)
# Out:
# User-ID
# 240403    199
# 203017    199
# 193458    199
# 2033      198
# 267061    198
#          ...
# 95420       6
# 95156       6
# 231313      6
# 95146       6
# 233397      6
# Length: 18812, dtype: int64

# %%
ratings_with_book_titles = ratings_df.merge(books_df,on='ISBN')
ratings_with_book_titles.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...

# %%
ratings_with_book_titles.drop(columns=["ISBN","Image-URL-S","Image-URL-M"],axis=1,inplace=True)

# %%
complete_df = ratings_with_book_titles.merge(users_df.drop("Age", axis=1), on="User-ID")
complete_df.head()
# Out:
#    User-ID  Book-Rating                                        Book-Title  \
# 0   276725            0                              Flesh Tones: A Novel
# 1     2313            5                              Flesh Tones: A Novel
# 2     2313            9     Ender's Game (Ender Wiggins Saga (Paperback))
# 3     2313            8             In Cold Blood (Vintage International)
# 4     2313            9  Divine Secrets of the Ya-Ya Sisterhood : A Novel
#
#         Book-Author Year-Of-Publication         Publisher  \
# 0        M. J. Rose                2002  Ballantine Books
# 1        M. J. Rose                2002  Ballantine Books
# 2  Orson Scott Card                1986         Tor Books
# 3     TRUMAN CAPOTE                1994           Vintage
# 4     Rebecca Wells                1996     HarperCollins
#
#                                          Image-URL-L               Location
# 0  http://images.amazon.com/images/P/034545104X.0...      tyler, texas, usa
# 1  http://images.amazon.com/images/P/034545104X.0...  cincinnati, ohio, usa
# 2  http://images.amazon.com/images/P/0812533550.0...  cincinnati, ohio, usa
# 3  http://images.amazon.com/images/P/0679745580.0...  cincinnati, ohio, usa
# 4  http://images.amazon.com/images/P/0060173289.0...  cincinnati, ohio, usa

# %%
complete_df['Location'] = complete_df['Location'].str.split(',').str[-1].str.strip()
complete_df.head()
# Out:
#    User-ID  Book-Rating                                        Book-Title  \
# 0   276725            0                              Flesh Tones: A Novel
# 1     2313            5                              Flesh Tones: A Novel
# 2     2313            9     Ender's Game (Ender Wiggins Saga (Paperback))
# 3     2313            8             In Cold Blood (Vintage International)
# 4     2313            9  Divine Secrets of the Ya-Ya Sisterhood : A Novel
#
#         Book-Author Year-Of-Publication         Publisher  \
# 0        M. J. Rose                2002  Ballantine Books
# 1        M. J. Rose                2002  Ballantine Books
# 2  Orson Scott Card                1986         Tor Books
# 3     TRUMAN CAPOTE                1994           Vintage
# 4     Rebecca Wells                1996     HarperCollins
#
#                                          Image-URL-L Location
# 0  http://images.amazon.com/images/P/034545104X.0...      usa
# 1  http://images.amazon.com/images/P/034545104X.0...      usa
# 2  http://images.amazon.com/images/P/0812533550.0...      usa
# 3  http://images.amazon.com/images/P/0679745580.0...      usa
# 4  http://images.amazon.com/images/P/0060173289.0...      usa

# %%
min_ratings_count_threshold=500
rating_counts= complete_df.groupby('Book-Title').count()['Book-Rating']
popular_books = rating_counts[rating_counts >= min_ratings_count_threshold].index

# %%
final_ratings =  complete_df[complete_df['Book-Title'].isin(popular_books)]
print(f"Number of ratings: {len(final_ratings)}")
final_ratings.head()
# Out:
# Number of ratings: 22541
#     User-ID  Book-Rating                           Book-Title    Book-Author  \
# 38     6543            0            The Lovely Bones: A Novel   Alice Sebold
# 39     6543            0                    The Da Vinci Code      Dan Brown
# 40     6543            0                          Wild Animus   Rich Shapero
# 53     6543            0  The Red Tent (Bestselling Backlist)  Anita Diamant
# 56     6543            9              The Secret Life of Bees  Sue Monk Kidd
#
#    Year-Of-Publication      Publisher  \
# 38                2002  Little, Brown
# 39                2003      Doubleday
# 40                2004        Too Far
# 53                1998    Picador USA
# 56                2003  Penguin Books
#
#                                           Image-URL-L Location
# 38  http://images.amazon.com/images/P/0316666343.0...      usa
# 39  http://images.amazon.com/images/P/0385504209.0...      usa
# 40  http://images.amazon.com/images/P/0971880107.0...      usa
# 53  http://images.amazon.com/images/P/0312195516.0...      usa
# 56  http://images.amazon.com/images/P/0142001740.0...      usa

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID'
                          ,values='Book-Rating')
pt.head()
# Out:
# User-ID                                          9       14      16      \
# Book-Title
# A Painted House                                     NaN     NaN     NaN
# A Time to Kill                                      NaN     NaN     NaN
# Angels &amp; Demons                                 NaN     NaN     NaN
# Bridget Jones's Diary                               NaN     NaN     NaN
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     NaN     NaN     NaN
#
# User-ID                                          51      67      114     \
# Book-Title
# A Painted House                                     NaN     NaN     NaN
# A Time to Kill                                      NaN     NaN     NaN
# Angels &amp; Demons                                 NaN     NaN    10.0
# Bridget Jones's Diary                               NaN     NaN     NaN
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     NaN     NaN     NaN
#
# User-ID                                          193     232     242     \
# Book-Title
# A Painted House                                     NaN     NaN     NaN
# A Time to Kill                                      NaN     NaN     NaN
# Angels &amp; Demons                                 NaN     NaN     NaN
# Bridget Jones's Diary                               NaN     0.0     NaN
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     NaN     NaN     NaN
#
# User-ID                                          243     ...  278418  278422  \
# Book-Title                                               ...
# A Painted House                                     7.0  ...     0.0     NaN
# A Time to Kill                                      NaN  ...     0.0     NaN
# Angels &amp; Demons                                 0.0  ...     NaN     6.0
# Bridget Jones's Diary                               NaN  ...     NaN     NaN
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     NaN  ...     NaN     NaN
#
# User-ID                                          278506  278514  278541  \
# Book-Title
# A Painted House                                     NaN     NaN     NaN
# A Time to Kill                                      NaN     NaN     NaN
# Angels &amp; Demons                                 NaN     NaN     NaN
# Bridget Jones's Diary                               NaN     NaN     NaN
# Divine Secrets of the Ya-Ya Sisterhood: A Novel     NaN     NaN     NaN
#
# User-ID                                          278543  278554  278633  \
# Book-Title
# A Painted House                                     NaN     NaN     NaN
# A Time to Kill                                      NaN     NaN     NaN
# Angels &amp; Demons                                 NaN     NaN     NaN
0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# User-ID                                             278633  278698  278843
# Book-Title
# A Painted House                                        0.0     0.0     0.0
# A Time to Kill                                         0.0     0.0     0.0
# Angels &amp; Demons                                    0.0     0.0     0.0
# Bridget Jones's Diary                                  2.0     0.0     8.0
# Divine Secrets of the Ya-Ya Sisterhood: A Novel        0.0     0.0     0.0
# Girl with a Pearl Earring                              0.0     0.0     0.0
# Harry Potter and the Chamber of Secrets (Book 2)       0.0     0.0     0.0
# Harry Potter and the Sorcerer's Stone (Harry Po...     0.0     0.0     8.0
# House of Sand and Fog                                  0.0     0.0     0.0
# Interview with the Vampire                             0.0     0.0     0.0
# Life of Pi                                             0.0     0.0     0.0
# Snow Falling on Cedars                                 0.0     0.0     0.0
# Summer Sisters                                         9.0     0.0     0.0
# The Brethren                                           0.0     0.0     0.0
# The Da Vinci Code                                      0.0     0.0     0.0
# The Firm                                               0.0     0.0     0.0
# The Girls' Guide to Hunting and Fishing                0.0     0.0     0.0
# The Joy Luck Club                                      0.0     0.0     0.0
# The Lovely Bones: A Novel                              9.0     0.0     0.0
# The Nanny Diaries: A Novel                             0.0     0.0     0.0
# The Notebook                                           0.0     0.0     0.0
# The Pelican Brief                                      0.0     0.0     0.0
# The Pilot's Wife : A Novel                             0.0     0.0     0.0
# The Red Tent (Bestselling Backlist)                    0.0     0.0     0.0
# The Runaway Jury                                       0.0     0.0     0.0
# The Secret Life of Bees                                0.0     0.0     0.0
# The Street Lawyer                                      0.0     0.0     0.0
# The Summons                                            0.0    10.0     0.0
# The Testament                                          0.0     0.0     0.0
# Timeline                                               0.0     0.0     0.0
# Where the Heart Is (Oprah's Book Club (Paperback))     0.0     0.0     0.0
# Wild Animus                                            0.0     0.0     0.0
#
# [32 rows x 11636 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity 

similarity_score = cosine_similarity(pt)


def recommend(book_name):
    index = np.where(pt.index==book_name)[0][0]
    similar_books = sorted(list(enumerate(similarity_score[index])),key=lambda x:x[1], reverse=True)[1:6]
    
    data = []
    
    for i in similar_books:
        item = []
        temp_df = books_df[books_df['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    return data

def print_available_books():
    return list(final_ratings['Book-Title'].unique())

def search_name_like(name):
    return list(final_ratings[final_ratings['Book-Title'].str.contains(name)]['Book-Title'].unique())

# %%
search_name_like("finance")
# Out:
# []

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# [["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'],
#  ["Bridget Jones's Diary",
#   'Helen Fielding',
#   'http://images.amazon.com/images/P/0330332775.01.MZZZZZZZ.jpg'],
#  ['A Time to Kill',
#   'JOHN GRISHAM',
#   'http://images.amazon.com/images/P/0440211727.01.MZZZZZZZ.jpg'],
#  ['Interview with the Vampire',
#   'Anne Rice',
#   'http://images.amazon.com/images/P/0345337662.01.MZZZZZZZ.jpg'],
#  ['The Firm',
#   'John Grisham',
#   'http://images.amazon.com/images/P/0385416342.01.MZZZZZZZ.jpg']]
